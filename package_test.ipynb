# %%
from ecosloader import api_client
# Out:
# /Users/jaeminiman/anaconda3/envs/pytorch/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# #### Client 테스트

# %%
api_key = 'HLOXWJTZRBR3KCAG5JU3'
client = api_client(api_key)

# %%
client.check_api_key()
# Out:
# Valid API key: HLOXWJTZRBR3KCAG5JU3

# %%
client.set_output_type('xls')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 client.set_output_type('xls')
#
# File ~/Documents/GitHub/macrowave_investing/ecosloader/ecos_api.py:170, in api_client.set_output_type(self, output_type)
#     163 def set_output_type(self, output_type):
#     164     """
#     165     API 출력 형식을 설정.
#     166
#     167     Args:
#     168         output_type (str): 출력 형식 ('xml' 또는 'json')
#     169     """
# --> 170     assert output_type in ['xml', 'json'], 'Output type should be "xml" or "json"'
#     171     self.output_type = output_type
#     172     print('Set output type: {}'.format(self.output_type))
#
# AssertionError: Output type should be "xml" or "json"

# %%
client.set_output_type('json')
# Out:
# Set output type: json

# %%
client.set_language('kr')
# Out:
# Language set to: kr

# %% [markdown]
# #### KOSPI 지수 불러오기

# %% [markdown]
# - index_no 5310

# %%
client.stats_codes.load_stats_code(path='https://github.com/jmlee8939/macrowave_investing/raw/refs/heads/main/data/stats_df.csv')

# %%
client.stats_codes.search_stats_code('주식시장')
# Out:
#      STAT_CODE           STAT_NAME GRP_CODE GRP_NAME ITEM_CODE  \
# 3142   901Y014  1.5.1.2. 주식시장(월,년)   Group1     계정항목   1010000
# 3143   901Y014  1.5.1.2. 주식시장(월,년)   Group1     계정항목   1010000
# 3144   901Y014  1.5.1.2. 주식시장(월,년)   Group1     계정항목   1020000
# 3145   901Y014  1.5.1.2. 주식시장(월,년)   Group1     계정항목   1020000
# 3146   901Y014  1.5.1.2. 주식시장(월,년)   Group1     계정항목   1030000
# 3147   901Y014  1.5.1.2. 주식시장(월,년)   Group1     계정항목   1030000
# 3148   901Y014  1.5.1.2. 주식시장(월,년)   Group1     계정항목   1040000
# 3149   901Y014  1.5.1.2. 주식시장(월,년)   Group1     계정항목   1040000
# 3150   901Y014  1.5.1.2. 주식시장(월,년)   Group1     계정항목   1050000
# 3151   901Y014  1.5.1.2. 주식시장(월,년)   Group1     계정항목   1050000
# 5310   802Y001    1.5.1.1. 주식시장(일)   Group1     계정항목   0001000
# 5311   802Y001    1.5.1.1. 주식시장(일)   Group1     계정항목   0002000
# 5312   802Y001    1.5.1.1. 주식시장(일)   Group1     계정항목   0003000
# 5313   802Y001    1.5.1.1. 주식시장(일)   Group1     계정항목   0030000
# 5314   802Y001    1.5.1.1. 주식시장(일)   Group1     계정항목   0087000
# 5315   802Y001    1.5.1.1. 주식시장(일)   Group1     계정항목   0088000
# 5316   802Y001    1.5.1.1. 주식시장(일)   Group1     계정항목   0089000
# 5317   802Y001    1.5.1.1. 주식시장(일)   Group1     계정항목   0090000
# 5318   802Y001    1.5.1.1. 주식시장(일)   Group1     계정항목   0091000
# 5319   802Y001    1.5.1.1. 주식시장(일)   Group1     계정항목   0113000
#
#                      ITEM_NAME P_ITEM_CODE P_ITEM_NAME CYCLE START_TIME  \
# 3142                 KOSPI_회사수     1000000    KOSPI 계열     A       1984
# 3143                 KOSPI_회사수     1000000    KOSPI 계열     M     200501
# 3144                 KOSPI_종목수     1000000    KOSPI 계열     A       1984
# 3145                 KOSPI_종목수     1000000    KOSPI 계열     M     200501
# 3146               KOSPI_상장주식수     1000000    KOSPI 계열     A       1984
# 3147               KOSPI_상장주식수     1000000    KOSPI 계열     M     200501
# 3148                KOSPI_시가총액     1000000    KOSPI 계열     A       1984
# 3149                KOSPI_시가총액     1000000    KOSPI 계열     M     200501
# 3150                 KOSPI_거래량     1000000    KOSPI 계열     A       1984
# 3151                 KOSPI_거래량     1000000    KOSPI 계열     M     200501
# 5310                   KOSPI지수         NaN         NaN     D   19950103
# 5311            거래량(주식시장, 잠정치)     0001000     KOSPI지수     D   20030102
# 5312          거래대금(주식시장 , 잠정치)     0001000     KOSPI지수     D   20030102
# 5313        외국인 순매수(주식시장, 잠정치)     0001000     KOSPI지수     D   20030102
# 5314   주식시장-거래량(만주, 시간외거래분 포함)     0001000     KOSPI지수     D   19950103
# 5315  주식시장-거래대금(억원, 시간외거래분 포함)     0001000     KOSPI지수     D   19950103
# 5316                  KOSDAQ지수         NaN         NaN     D   20030102
# 5317      거래량(만주 : 코스닥시장, 잠정치)     0089000    KOSDAQ지수     D   20030102
# 5318     거래대금(억원 : 코스닥시장, 잠정치)     0089000    KOSDAQ지수     D   20030102
# 5319       외국인 순매수(코스닥시장, 잠정치)     0089000    KOSDAQ지수     D   20030102
#
#       END_TIME  DATA_CNT        UNIT_NAME  WEIGHT
# 3142      2023        40                사     NaN
# 3143    202411       239                사     NaN
# 3144      2023        40               종목     NaN
# 3145    202411       239               종목     NaN
# 3146      2023        40               주      NaN
# 3147    202411       239               주      NaN
# 3148      2023        40              천원      NaN
# 3149    202411       239              천원      NaN
# 3150      2023        40               주      NaN
# 3151    202411       239               주      NaN
# 5310  20250106      7604  1980.01.04=100      NaN
# 5311  20250106      5435               만주     NaN
# 5312  20250106      5435              억원      NaN
# 5313  20250106      5439              억원      NaN
# 5314  20250103      7635               만주     NaN
# 5315  20250103      7635              억원      NaN
# 5316  20250106      5439  1996.07.01=1000     NaN
# 5317  20250106      5439               만주     NaN
# 5318  20250106      5439              억원      NaN
# 5319  20250106      5439              억원      NaN

# %%
client.stats_codes.stats_codes_info.loc[5310]
# Out:
# STAT_CODE               802Y001
# STAT_NAME      1.5.1.1. 주식시장(일)
# GRP_CODE                 Group1
# GRP_NAME                   계정항목
# ITEM_CODE               0001000
# ITEM_NAME               KOSPI지수
# P_ITEM_CODE                 NaN
# P_ITEM_NAME                 NaN
# CYCLE                         D
# START_TIME             19950103
# END_TIME               20250106
# DATA_CNT                   7604
# UNIT_NAME       1980.01.04=100
# WEIGHT                      NaN
# Name: 5310, dtype: object

# %%
client.stat_search(stat_code='802Y001', first=1, end=7604, interval='D', starttime='19950103', endtime='20250106', subcode1='0001000')
# Out:
#      STAT_CODE         STAT_NAME ITEM_CODE1 ITEM_NAME1 ITEM_CODE2 ITEM_NAME2  \
# 0      802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
# 1      802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
# 2      802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
# 3      802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
# 4      802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
# ...        ...               ...        ...        ...        ...        ...
# 7599   802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
# 7600   802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
# 7601   802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
# 7602   802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
# 7603   802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
#
#      ITEM_CODE3 ITEM_NAME3 ITEM_CODE4 ITEM_NAME4        UNIT_NAME   WGT  \
# 0          None       None       None       None  1980.01.04=100   None
# 1          None       None       None       None  1980.01.04=100   None
# 2          None       None       None       None  1980.01.04=100   None
# 3          None       None       None       None  1980.01.04=100   None
# 4          None       None       None       None  1980.01.04=100   None
# ...         ...        ...        ...        ...              ...   ...
# 7599       None       None       None       None  1980.01.04=100   None
# 7600       None       None       None       None  1980.01.04=100   None
# 7601       None       None       None       None  1980.01.04=100   None
# 7602       None       None       None       None  1980.01.04=100   None
# 7603       None       None       None       None  1980.01.04=100   None
#
#           TIME DATA_VALUE
# 0     19950103    1013.57
# 1     19950104     997.01
# 2     19950105     976.06
# 3     19950106     975.32
# 4     19950107      988.8
# ...        ...        ...
# 7599  20241227    2404.77
# 7600  20241230    2399.49
# 7601  20250102    2398.94
# 7602  20250103    2441.92
# 7603  20250106    2488.64
#
# [7604 rows x 14 columns]

# %%
client.todays_100_stat()
# Out:
#     CLASS_NAME   KEYSTAT_NAME DATA_VALUE     CYCLE   UNIT_NAME
# 0         시장금리      한국은행 기준금리          3  20250116          %
# 1         시장금리       콜금리(익일물)      3.071  20250116          %
# 2         시장금리   KORIBOR(3개월)       3.06  20250117          %
# 3         시장금리     CD수익률(91일)       2.99  20250117          %
# 4         시장금리  통안증권수익률(364일)      2.606  20250117          %
# ..         ...            ...        ...       ...         ...
# 96      부동산 가격       주택매매가격지수       96.4    202411  2021.6=100
# 97      부동산 가격       주택전세가격지수       93.7    202411  2021.6=100
# 98      부동산 가격    지가변동률(전기대비)      0.188    202411          %
# 99     국제원자재가격      Duba유(현물)         74    202412       달러/배럴
# 100    국제원자재가격              금    2640.61    202412         달러
#
# [101 rows x 5 columns]

# %%
client.stat_search_index(5310)
# Out:
#      STAT_CODE         STAT_NAME ITEM_CODE1 ITEM_NAME1 ITEM_CODE2 ITEM_NAME2  \
# 0      802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
# 1      802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
# 2      802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
# 3      802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
# 4      802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
# ...        ...               ...        ...        ...        ...        ...
# 7599   802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
# 7600   802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
# 7601   802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
# 7602   802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
# 7603   802Y001  1.5.1.1. 주식시장(일)    0001000    KOSPI지수       None       None
#
#      ITEM_CODE3 ITEM_NAME3 ITEM_CODE4 ITEM_NAME4        UNIT_NAME   WGT  \
# 0          None       None       None       None  1980.01.04=100   None
# 1          None       None       None       None  1980.01.04=100   None
# 2          None       None       None       None  1980.01.04=100   None
# 3          None       None       None       None  1980.01.04=100   None
# 4          None       None       None       None  1980.01.04=100   None
# ...         ...        ...        ...        ...              ...   ...
# 7599       None       None       None       None  1980.01.04=100   None
# 7600       None       None       None       None  1980.01.04=100   None
# 7601       None       None       None       None  1980.01.04=100   None
# 7602       None       None       None       None  1980.01.04=100   None
# 7603       None       None       None       None  1980.01.04=100   None
#
#           TIME DATA_VALUE
# 0     19950103    1013.57
# 1     19950104     997.01
# 2     19950105     976.06
# 3     19950106     975.32
# 4     19950107      988.8
# ...        ...        ...
# 7599  20241227    2404.77
# 7600  20241230    2399.49
# 7601  20250102    2398.94
# 7602  20250103    2441.92
# 7603  20250106    2488.64
#
# [7604 rows x 14 columns]

# %%
client.stats_codes.update_stats_code(api_key)
# Out:
# 통계 코드 총 593 개 확인
# Processing stats codes:  17%|█▋        | 99/593 [00:35<01:22,  6.02it/s]
# 100 948
# Processing stats codes:  34%|███▎      | 199/593 [02:08<01:24,  4.64it/s]
# 200 1901
# Processing stats codes:  50%|█████     | 299/593 [04:07<07:03,  1.44s/it]
# 300 2877
# Processing stats codes:  67%|██████▋   | 399/593 [06:05<00:53,  3.62it/s]
# 400 3841
# Processing stats codes:  84%|████████▍ | 499/593 [07:40<00:37,  2.48it/s]
# 500 4775
# Processing stats codes: 100%|██████████| 593/593 [09:34<00:00,  1.03it/s]
